# %%
from hmm_module import (create_transition_matrix, 
                        p_z1_given_c, 
                        simulate_c, 
                        simulate_z, 
                        simulate_x, 
                        simulate_hmm,
                        plot_single,
                        plot_freq,
                        plot_all,
                        plot_mean,
                        make_datasets,
                        emission_matrix,
                        forward_C,
                        backward_C,
                        compute_smoothed_prob,
                        posterior_Z,
                        hmm_pipeline
                        )

# %%
# suggested values
alpha_val = 0.9
beta_val = 0.2
small_gamma_val = 0.1
lambda_0 = 1
lambda_1 = 5

n = 10
big_T = 100
